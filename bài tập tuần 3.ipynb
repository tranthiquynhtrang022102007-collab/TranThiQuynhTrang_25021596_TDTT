# %%
a= int(input("nhap a:"))
b=int(input("nhap b:"))
print("truoc khi hoan doi:a=",a,",b=",b)
a=a^b
b=a^b
a=a^b
print("sau khi hoan doi:a=",a,",b=",b)
# Out:
# truoc khi hoan doi:a= 22 ,b= 10
# sau khi hoan doi:a= 10 ,b= 22

# %%
#W3A3
def is_power_of_two(n):
    return n>0 and (n&(n-1))==0
num= int(input("nhap so n:"))
if is_power_of_two(num):
    print(num,"la luy thua cua 2")
else:
    print(num,"khong la luy thua cua 2")
# Out:
# 22 khong la luy thua cua 2

# %%
m,n=map(int,input().split())
kq=m//n
print("ket qua lam tron xuong:", kq)
# Out:
# ket qua lam tron xuong: 2

# %%
m,n=map(int,input().split())


kq=(m+n-1)//n
print("ket qua lam tron len:",kq)
# Out:
# ket qua lam tron len: 1

# %%
x= int(input())
if x%2==0:
    print("even")
else:
    print("old")
# Out:
# even

# %%
a,b= map(int,input().split())
if a<0 and b<0:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
a= input()
b=input()
if len(a) > len(b):
    print("true")
else:
    print("false")
# Out:
# true

# %%
a,b,c=map(int,input().split())
if a+b>c and a+c>b and b+c>a:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
a,b,c,d=map(int,input().split())
max_num=a
if b> max_num:
    max_num=b
if c>max_num:
    max_num=c
if d>max_num:
    max_num=d
print("so lon nhat:",max_num)
# Out:
# so lon nhat: 1

# %%
a,b,c= map(int,input().split())
if a+b<c or a+c<b or b+c<a:
    print("khong phai tam giac")
elif a==b==c:
    print("la tam giac deu")
elif a==b or c==a or b==c:
    print ("la tam giac can")
else:
    print( "la tam giac thuong")
# Out:
# la tam giac deu

# %%
n= int(input("nhap nam:"))
if (n%4==0 and n% 100!=0) or (n%400==0):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
a= float(input("nhap a:"))
b=float(input("nhap b"))
if  a != 0:
    x=-b/a
    print("nghiệm x=", round(x,2))
else:
    if b==0:
        print("vo so nghiem")
    else:
        print("vô nghiệm")
# Out:
# nghiệm x= -2.5

# %%
x= int(input( "nhập điểm của học sinh:"))
if x>=8:
    print("giỏi")
elif x>=6.5:
    print("khá")
elif x>= 5.0:
    print("trung bình")
else:
    print("yếu")
# Out:
# trung bình

# %%
x= float(input("nhap 1 so thuc:"))
if x>=0:
    down=int(x)
else:
    down= int(x)-1 if x!= int(x) else int(x)
if x>=0:
        up= int(x)+1 if x !=int(x) else int(x)
else: 
    up= int(x)
if x- int(x)>= 0.5:
    nearest= int(x)+1
elif x-int(x)<=-0.5:
    nearest= int(x)-1
else:
    nearest= int(x)
print( down, up,nearest)
# Out:
# 7 8 7

# %%
a,b,c,d=map(int,input().split())
if b%a!=0:
    print("không là csn")
else:
    cd=b/a
    if c/b==cd and d/c==cd:
        print("là csn")
    else:
        print("không là csn")
# Out:
# là csn
