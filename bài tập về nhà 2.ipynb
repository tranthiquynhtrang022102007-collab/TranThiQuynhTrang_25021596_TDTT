# %%
a= int(input("nhập số a:"))
b=int(input(" nhập số b:"))
S=a*b
print("diện tích hình chữ nhật:",S)
P=2*(a+b)
print(" chu vi hình chữ nhật:",P)
# Out:
# diện tích hình chữ nhật: 35
#  chu vi hình chữ nhật: 24

# %%
r=int(input(" nhập bán kính r:"))
pi=3.14
S=pi*r*r
print("diện tích hình tròn:",S)
C=2*pi*r
print("chu vi hình tròn:",C)
# Out:
# diện tích hình tròn: 452.15999999999997
# chu vi hình tròn: 75.36

# %%
a=int(input("nhập số a:"))
b=int(input("nhập số b:"))
c=int(input("nhập số c:"))
if a+b<c or a+c<b or b+c<a:
    print("khong phai la 3 canh cua tam giac")
elif a==b==c:
    print("tam giac deu")
elif a==b or a==c or b==c:
    print ("tam giac can")
else :
    print("tam giac thuong")
    P= a+b+c
    print("chu vi tam giac:",P)
    p=P/2
    S=(p*(p-a)*(p-b)*(p-c))**0.5
    print("dien tich tam giac:",S)
# Out:
# tam giac thuong
# chu vi tam giac: 29
# dien tich tam giac: 34.977671449083054

# %%
a=int(input("nhap so a:"))
b= int(input("nhap so b:"))
if a==0:
    if b==0:
        print("phuong trinh vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
else :
    x=-b/a
    print("phuong trinh co nghiem x=",x)
# Out:
# phuong trinh co nghiem x= -1.2

# %%
a=int(input("nhap so a:"))
b=int(input("nhap so b:"))
c= int(input("nhap so c:"))
delta=b**2-4*a*c
if delta<0:
    print("phuong trinh vo nghiem")
elif delta==0:
    x=-b/(2*a)
    print("phuong trinh co nghiem kep x=",x)
else:
    x1=(-b+delta**0.5)/(2*a)
    x2=(-b-delta**0.5)/(2*a)
    print("phuong trinh co 2 nghiem phan biet x1=",x1," va x2=",x2)
# Out:
# phuong trinh vo nghiem

# %%
#bài 6:
a,b,c,d=map(int, input().split())
if a>b and a>c and a>d:
    print ("so lon nhat la :",a)
elif b>a and b>c and b>d:
    print (" so lon nhat la :",b)
elif c>a and c>b and c>d:
    print (" so lon nhat la:",c)
else :
    print(" so lon nhat la:",d)
# Out:
#  so lon nhat la: 7

# %%
#bài 7:
a,b,c,d =map(int,input().split())
min_num=a
if b< min_num:
    min_num=b
if c< min_num:
    min_num=c
if d< min_num:
    min_num=d 
print("gia tri nho nhat la:", min_num)
# Out:
# gia tri nho nhat la: 6

# %%
#bài 8:
a,b,n=map(int,input().split())
c,d,m= map(int,input().split())
K=a*d-c*b
Kx=n*d-m*b
Ky=m*a-n*b
if K==0:
    if Kx==0 and Ky==0:
        print("he phuong trinh vo so nghiem")
    else:
        print( "he phhuong trinh vo nghiem")
else:
        x=Kx/K
        y=Ky/K
        print("he phuong trinh có nghem x=",x,"và y=",y)
# Out:
# he phuong trinh có nghem x= -1.0 và y= -0.0

# %%
Ix= int(input("nhap hoanh do tam:"))
Iy= int(input("nhap vao tung do tam:"))
r= int(input("nhap vao ban kinh:"))
Ax=int(input("nhap hoanh do A:"))
Ay= int(input("nhap tung do A:"))
if r**2==(Ix-Ax)**2+(Iy-Ay)**2 or r**2>(Ix-Ax)**2+(Iy-Ay)**2:
    print("điểm A nằm thuộc đường tròn")
else:
    print("điểm A khong thuộc đường tròn")
# Out:
# điểm A khong thuộc đường tròn

# %%
x,y= map(int,input().split())
A= x**y
print("x^y=",A)
# Out:
# x^y= 1024
